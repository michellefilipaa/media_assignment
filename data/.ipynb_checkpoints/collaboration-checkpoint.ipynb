# %% [markdown]
# # Collaboration

# %%
import numpy as np
import itertools
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
user_ratings = pd.read_csv('../data/user_ratings.csv')
movies = pd.read_csv('../data/all_data.csv')

# %%
df = pd.merge(user_ratings, movies, on='showId', how='left')
genres = df['category'].str.get_dummies('|')
df = pd.concat([df, genres], axis=1)
df = df[['userId', 'showId', 'rating', 'CBBC', 'Comedy', 'Documentaries', 'Entertainment', 'From the Archives', 'Science & Nature', 'Sports']]

# %%
df
# Out:
#             userId  showId  rating  CBBC  Comedy  Documentaries  \
# 0     sports_fan_1     134       3     0       0              0
# 1     sports_fan_1     226       5     0       0              0
# 2     sports_fan_1     224       4     0       0              0
# 3     sports_fan_1     140       1     0       0              0
# 4     sports_fan_1     121       5     0       0              0
# ...            ...     ...     ...   ...     ...            ...
# 5176        sine_1     136       3     0       0              0
# 5177        sine_1      52       3     0       0              0
# 5178        zane_1     211       2     0       0              0
# 5179        zane_1     122       1     0       0              0
# 5180        zane_1     228       5     0       0              0
#
#       Entertainment  From the Archives  Science & Nature  Sports
# 0                 0                  0                 0       1
# 1                 0                  0                 1       0
# 2                 0                  0                 1       0
# 3                 0                  0                 0       1
# 4                 0                  0                 0       1
# ...             ...                ...               ...     ...
# 5176              0                  0                 0       1
# 5177              0                  0                 0       0
# 5178              0                  0                 0       0
# 5179              0                  0                 0       1
# 5180              0                  0                 1       0
#
# [5181 rows x 10 columns]

# %% [markdown]
# # Collaborative filtering (Jaccard similarity)
# In the function below the jaccard similarity is written based on the ratings of the users

# %%
import pandas as pd
import os

def get_jaccard_recommendations(user_ids, df, movies):
    users = df.groupby('userId')['showId'].apply(set)
    
    group_movies = set()
    for user_id in user_ids:
        group_movies.update(users.get(user_id, set()))
    
    similar_users = []
    new_content = set()  # Use set to store unique recommended items

    for user, value in users.items():
        if user in user_ids:
            continue
        
        other_user_set = value
        
        # Calculate Jaccard similarity for each user separately
        intersection = len(group_movies.intersection(other_user_set))
        union = len(group_movies.union(other_user_set))
        user_similarity = float(intersection) / union

        # Tweak this parameter. Closer to 0.0 is more similar.
        if user_similarity < 0.1 and user_similarity != 0.00:
            differences = group_movies.symmetric_difference(other_user_set)
            new_content.update(differences)  

            # Add the user to similar_users
            similar_users.append(user)
            
            if len(similar_users) >= 15:  # Limit to 10 similar users
                break
    
    # Create DataFrame with unique recommended show IDs
    df_recommendations = pd.DataFrame(list(new_content), columns=['showId'])
    
    # Merge recommendations DataFrame with movies DataFrame based on showId
    df_recommendations_with_info = pd.merge(df_recommendations, movies, on='showId', how='left')
    
    # Define the directory path
    directory = "../data/recommendations"
    
    # Use the defined directory path to save recommendations to CSV
    csv_file_path = os.path.join(directory, "collaboration_" + "_".join(user_ids) + ".csv")
    
    # Save recommendations to CSV
    df_recommendations_with_info.to_csv(csv_file_path, index=False)
    
    return df_recommendations_with_info

# %%
user_ids = ["michelle_1", "asha_1"]  # List of user IDs in the group
recommendations = get_jaccard_recommendations(user_ids, df, movies)
recommendations
# Out:
#     showId          category  \
# 0        1              CBBC
# 1        2              CBBC
# 2        3              CBBC
# 3        4              CBBC
# 4        5              CBBC
# ..     ...               ...
# 91     230  Science & Nature
# 92     231  Science & Nature
# 93     232  Science & Nature
# 94     236  Science & Nature
# 95     239  Science & Nature
#
#                                                 title  \
# 0   Operation Ouch! - Series 9: 11. Blink and You’...
# 1   The Worst Witch - Series 4: 1. The Three Impos...
# 2    Shaun the Sheep - Series 4: 6. The Smelly Farmer
# 3   Pokémon: Black and White - Movies: Black - Vic...
# 4    Deadly 60 - Series 2: 1. Baja California, Mexico
# ..                                                ...
# 91       The Green Planet - Series 1: 5. Human Worlds
# 92                                           Aquarela
# 93  Zoo Quest - Zoo Quest for a Dragon: 5. Bali - ...
# 94              Born to Be Wild - Series 2: Episode 1
# 95  Forces of Nature with Brian Cox - 3. The Moth ...
#
#                                                  tags age_rating  \
# 0   BBC, iPlayer, TV, Operation Ouch!, Series 9: 1...         PG
# 1   BBC, iPlayer, TV, The Worst Witch, Series 4: 1...         PG
# 2   BBC, iPlayer, TV, Shaun the Sheep, Series 4: 6...          U
# 3   BBC, iPlayer, TV, Pokémon: Black and White, Mo...         PG
# 4   BBC, iPlayer, TV, Deadly 60, Series 2: 1. Baja...         PG
# ..                                                ...        ...
# 91  BBC, iPlayer, TV, The Green Planet, Series 1: ...          U
# 92                         BBC, iPlayer, TV, Aquarela         12
# 93  BBC, iPlayer, TV, Zoo Quest, Zoo Quest for a D...         PG
# 94  BBC, iPlayer, TV, Born to Be Wild, Series 2: E...         12
# 95  BBC, iPlayer, TV, Forces of Nature with Brian ...          U
#
#                     rating_description  \
# 0   injury detail, rude humour, threat
# 1                               threat
# 2                                clean
# 3    contains mild violence and threat
# 4                     upsetting scenes
# ..                                 ...
# 91                               clean
# 92                   distressing scene
# 93        infrequent mild bad language
# 94                 dangerous behaviour
# 95                               clean
#
#                                           description  representation  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...             3.0
# 1   A botched potions experiment leaves Mildred wi...             3.0
# 2   Shaun, Bitzer and the flock decide to give the...             NaN
# 3   Can Ash awaken Reshiram to help him rescue Vic...             NaN
# 4   In Mexico, Steve Backshall takes to the water ...             1.0
# ..                                                ...             ...
# 91  Two out of five plants are threatened, but peo...             3.0
# 92  A cinematic journey through the transformative...             NaN
# 93  David Attenborough encounters scaly anteaters ...             3.0
# 94  A look behind the scenes at the Scottish SPCA’...             1.0
# 95  Professor Brian Cox investigates the ingredien...             1.0
#
#    duration_txt  duration_sec     first_broadcast  \
# 0       28 mins          1692     5pm 17 Mar 2021
# 1       28 mins          1693         27 Jan 2020
# 2        7 mins           425  3:50pm 10 Feb 2014
# 3       92 mins          5497          3 Dec 2021
# 4       28 mins          1680   5:15pm 8 Jul 2010
# ..          ...           ...                 ...
# 91      58 mins          3450          6 Feb 2022
# 92      82 mins          4939         25 Aug 2021
# 93      30 mins          1789   8:15pm 2 Nov 1956
# 94      58 mins          3480     8pm 19 Jul 2021
# 95      58 mins          3501         18 Jul 2016
#
#                                        synopsis_small  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   A botched potions experiment leaves Mildred wi...
# 2   Shaun, Bitzer and the flock decide to give the...
# 3   Can Ash awaken Reshiram to help him rescue Vic...
# 4   In Mexico, Steve Backshall takes to the water ...
# ..                                                ...
# 91  Two out of five plants are threatened, but peo...
# 92  A cinematic journey through the transformative...
# 93  David Attenborough encounters scaly anteaters ...
# 94  A look behind the scenes at the Scottish SPCA’...
# 95  Professor Brian Cox investigates the ingredien...
#
#                                       synopsis_medium  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   When a botched potions experiment leaves Mildr...
# 2   Animated series. The farmer's personal hygiene...
# 3   Can Ash awaken legendary Pokémon Reshiram to h...
# 4   Wildlife series. On a trip to Mexico, Steve Ba...
# ..                                                ...
# 91  Two out of five wild plants are threatened wit...
# 92  A cinematic journey through the transformative...
# 93  First transmitted in 1956, the Zoo Quest team ...
# 94  April helps hand-rear Padme the orphaned fox c...
# 95  Professor Brian Cox reveals how Earth's beauty...
#
#                                        synopsis_large  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1                                       No data found
# 2   The farmer's personal hygiene leaves much to b...
# 3   When Ash, Iris and Cilan enter a battle compet...
# 4   Steve travels to the deadliest desert on the p...
# ..                                                ...
# 91  We rely on plants for almost everything, inclu...
# 92  A cinematic journey through the transformative...
# 93  First transmitted in 1956, David Attenborough ...
# 94  It’s the start of spring at the SSPCA Wildlife...
# 95  Professor Brian Cox shows how Earth's basic in...
#
#                                                 image
# 0   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 1   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 2   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 3   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 4   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# ..                                                ...
# 91  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 92  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 93  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 94  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 95  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
#
# [96 rows x 15 columns]

# %%
user_ids = ["sine_1", "zang_1", "zane_1"]  # List of user IDs in the group
recommendations = get_jaccard_recommendations(user_ids, df, movies)
recommendations
# Out:
#     showId          category  \
# 0        1              CBBC
# 1        2              CBBC
# 2        3              CBBC
# 3        4              CBBC
# 4        6              CBBC
# ..     ...               ...
# 85     230  Science & Nature
# 86     231  Science & Nature
# 87     232  Science & Nature
# 88     237  Science & Nature
# 89     239  Science & Nature
#
#                                                 title  \
# 0   Operation Ouch! - Series 9: 11. Blink and You’...
# 1   The Worst Witch - Series 4: 1. The Three Impos...
# 2    Shaun the Sheep - Series 4: 6. The Smelly Farmer
# 3   Pokémon: Black and White - Movies: Black - Vic...
# 4   The Next Step - Series 4: 18. Your Time Is Gon...
# ..                                                ...
# 85       The Green Planet - Series 1: 5. Human Worlds
# 86                                           Aquarela
# 87  Zoo Quest - Zoo Quest for a Dragon: 5. Bali - ...
# 88                                  Shark - Episode 3
# 89  Forces of Nature with Brian Cox - 3. The Moth ...
#
#                                                  tags age_rating  \
# 0   BBC, iPlayer, TV, Operation Ouch!, Series 9: 1...         PG
# 1   BBC, iPlayer, TV, The Worst Witch, Series 4: 1...         PG
# 2   BBC, iPlayer, TV, Shaun the Sheep, Series 4: 6...          U
# 3   BBC, iPlayer, TV, Pokémon: Black and White, Mo...         PG
# 4   BBC, iPlayer, TV, The Next Step, Series 4: 18....          U
# ..                                                ...        ...
# 85  BBC, iPlayer, TV, The Green Planet, Series 1: ...          U
# 86                         BBC, iPlayer, TV, Aquarela         12
# 87  BBC, iPlayer, TV, Zoo Quest, Zoo Quest for a D...         PG
# 88                 BBC, iPlayer, TV, Shark, Episode 3         15
# 89  BBC, iPlayer, TV, Forces of Nature with Brian ...          U
#
#                     rating_description  \
# 0   injury detail, rude humour, threat
# 1                               threat
# 2                                clean
# 3    contains mild violence and threat
# 4                                clean
# ..                                 ...
# 85                               clean
# 86                   distressing scene
# 87        infrequent mild bad language
# 88             scenes of animal threat
# 89                               clean
#
#                                           description  representation  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...             3.0
# 1   A botched potions experiment leaves Mildred wi...             3.0
# 2   Shaun, Bitzer and the flock decide to give the...             NaN
# 3   Can Ash awaken Reshiram to help him rescue Vic...             NaN
# 4   As James, Eldon, and West compete in London, R...             3.0
# ..                                                ...             ...
# 85  Two out of five plants are threatened, but peo...             3.0
# 86  A cinematic journey through the transformative...             NaN
# 87  David Attenborough encounters scaly anteaters ...             3.0
# 88  An international team of scientists is trying ...             NaN
# 89  Professor Brian Cox investigates the ingredien...             1.0
#
#    duration_txt  duration_sec     first_broadcast  \
# 0       28 mins          1692     5pm 17 Mar 2021
# 1       28 mins          1693         27 Jan 2020
# 2        7 mins           425  3:50pm 10 Feb 2014
# 3       92 mins          5497          3 Dec 2021
# 4       22 mins          1302  4:30pm 28 Nov 2016
# ..          ...           ...                 ...
# 85      58 mins          3450          6 Feb 2022
# 86      82 mins          4939         25 Aug 2021
# 87      30 mins          1789   8:15pm 2 Nov 1956
# 88      58 mins          3480     9pm 21 May 2015
# 89      58 mins          3501         18 Jul 2016
#
#                                        synopsis_small  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   A botched potions experiment leaves Mildred wi...
# 2   Shaun, Bitzer and the flock decide to give the...
# 3   Can Ash awaken Reshiram to help him rescue Vic...
# 4   As James, Eldon, and West compete in London, R...
# ..                                                ...
# 85  Two out of five plants are threatened, but peo...
# 86  A cinematic journey through the transformative...
# 87  David Attenborough encounters scaly anteaters ...
# 88  An international team of scientists is trying ...
# 89  Professor Brian Cox investigates the ingredien...
#
#                                       synopsis_medium  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   When a botched potions experiment leaves Mildr...
# 2   Animated series. The farmer's personal hygiene...
# 3   Can Ash awaken legendary Pokémon Reshiram to h...
# 4   Reality-style drama series. As James, Eldon, a...
# ..                                                ...
# 85  Two out of five wild plants are threatened wit...
# 86  A cinematic journey through the transformative...
# 87  First transmitted in 1956, the Zoo Quest team ...
# 88  Wildlife series on the sharks of the world. Sh...
# 89  Professor Brian Cox reveals how Earth's beauty...
#
#                                        synopsis_large  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1                                       No data found
# 2   The farmer's personal hygiene leaves much to b...
# 3   When Ash, Iris and Cilan enter a battle compet...
# 4   As James, Eldon, and West compete in London, R...
# ..                                                ...
# 85  We rely on plants for almost everything, inclu...
# 86  A cinematic journey through the transformative...
# 87  First transmitted in 1956, David Attenborough ...
# 88  Sharks are among the most misunderstood predat...
# 89  Professor Brian Cox shows how Earth's basic in...
#
#                                                 image
# 0   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 1   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 2   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 3   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 4   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# ..                                                ...
# 85  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 86  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 87  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 88  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 89  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
#
# [90 rows x 15 columns]

# %%
user_ids = ["sine_1", "asha_1"]  # List of user IDs in the group
recommendations = get_jaccard_recommendations(user_ids, df, movies)
recommendations
# Out:
#     showId          category  \
# 0        1              CBBC
# 1        2              CBBC
# 2        3              CBBC
# 3        4              CBBC
# 4        5              CBBC
# ..     ...               ...
# 84     224  Science & Nature
# 85     226  Science & Nature
# 86     229  Science & Nature
# 87     231  Science & Nature
# 88     232  Science & Nature
#
#                                                 title  \
# 0   Operation Ouch! - Series 9: 11. Blink and You’...
# 1   The Worst Witch - Series 4: 1. The Three Impos...
# 2    Shaun the Sheep - Series 4: 6. The Smelly Farmer
# 3   Pokémon: Black and White - Movies: Black - Vic...
# 4    Deadly 60 - Series 2: 1. Baja California, Mexico
# ..                                                ...
# 84                Arctic with Bruce Parry - 4. Canada
# 85                          Frozen Planet - 2. Spring
# 86            Great Barrier Reef - 3. Reef and Beyond
# 87                                           Aquarela
# 88  Zoo Quest - Zoo Quest for a Dragon: 5. Bali - ...
#
#                                                  tags age_rating  \
# 0   BBC, iPlayer, TV, Operation Ouch!, Series 9: 1...         PG
# 1   BBC, iPlayer, TV, The Worst Witch, Series 4: 1...         PG
# 2   BBC, iPlayer, TV, Shaun the Sheep, Series 4: 6...          U
# 3   BBC, iPlayer, TV, Pokémon: Black and White, Mo...         PG
# 4   BBC, iPlayer, TV, Deadly 60, Series 2: 1. Baja...         PG
# ..                                                ...        ...
# 84  BBC, iPlayer, TV, Arctic with Bruce Parry, 4. ...         12
# 85         BBC, iPlayer, TV, Frozen Planet, 2. Spring         PG
# 86  BBC, iPlayer, TV, Great Barrier Reef, 3. Reef ...          U
# 87                         BBC, iPlayer, TV, Aquarela         12
# 88  BBC, iPlayer, TV, Zoo Quest, Zoo Quest for a D...         PG
#
#                     rating_description  \
# 0   injury detail, rude humour, threat
# 1                               threat
# 2                                clean
# 3    contains mild violence and threat
# 4                     upsetting scenes
# ..                                 ...
# 84                       mild language
# 85                      animal hunting
# 86                               clean
# 87                   distressing scene
# 88        infrequent mild bad language
#
#                                           description  representation  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...             3.0
# 1   A botched potions experiment leaves Mildred wi...             3.0
# 2   Shaun, Bitzer and the flock decide to give the...             NaN
# 3   Can Ash awaken Reshiram to help him rescue Vic...             NaN
# 4   In Mexico, Steve Backshall takes to the water ...             1.0
# ..                                                ...             ...
# 84  Bruce travels to the far north of Canada to li...             1.0
# 85  Spring arrives in the polar regions, and the s...             NaN
# 86  A look at the creatures who travel for thousan...             NaN
# 87  A cinematic journey through the transformative...             NaN
# 88  David Attenborough encounters scaly anteaters ...             3.0
#
#    duration_txt  duration_sec     first_broadcast  \
# 0       28 mins          1692     5pm 17 Mar 2021
# 1       28 mins          1693         27 Jan 2020
# 2        7 mins           425  3:50pm 10 Feb 2014
# 3       92 mins          5497          3 Dec 2021
# 4       28 mins          1680   5:15pm 8 Jul 2010
# ..          ...           ...                 ...
# 84      59 mins          3568         26 Apr 2011
# 85      58 mins          3463          2 Nov 2011
# 86      59 mins          3546  8:10pm 15 Jan 2012
# 87      82 mins          4939         25 Aug 2021
# 88      30 mins          1789   8:15pm 2 Nov 1956
#
#                                        synopsis_small  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   A botched potions experiment leaves Mildred wi...
# 2   Shaun, Bitzer and the flock decide to give the...
# 3   Can Ash awaken Reshiram to help him rescue Vic...
# 4   In Mexico, Steve Backshall takes to the water ...
# ..                                                ...
# 84  Bruce travels to the far north of Canada to li...
# 85  Spring arrives in the polar regions, and the s...
# 86  A look at the creatures who travel for thousan...
# 87  A cinematic journey through the transformative...
# 88  David Attenborough encounters scaly anteaters ...
#
#                                       synopsis_medium  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1   When a botched potions experiment leaves Mildr...
# 2   Animated series. The farmer's personal hygiene...
# 3   Can Ash awaken legendary Pokémon Reshiram to h...
# 4   Wildlife series. On a trip to Mexico, Steve Ba...
# ..                                                ...
# 84  Bruce travels to the far north of Canada to li...
# 85  Documentary series. It's spring in the polar r...
# 86  Monty Halls explores Australia's natural wonde...
# 87  A cinematic journey through the transformative...
# 88  First transmitted in 1956, the Zoo Quest team ...
#
#                                        synopsis_large  \
# 0   Why is Dr Xand dressed as a bird in the lab? F...
# 1                                       No data found
# 2   The farmer's personal hygiene leaves much to b...
# 3   When Ash, Iris and Cilan enter a battle compet...
# 4   Steve travels to the deadliest desert on the p...
# ..                                                ...
# 84  Bruce travels to the far north of Canada to li...
# 85  Spring arrives in the polar regions, and the s...
# 86  The Great Barrier Reef is vitally linked to th...
# 87  A cinematic journey through the transformative...
# 88  First transmitted in 1956, David Attenborough ...
#
#                                                 image
# 0   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 1   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 2   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 3   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 4   https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# ..                                                ...
# 84  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 85  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 86  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 87  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
# 88  https://ichef.bbci.co.uk/images/ic/1200x675/p0...
#
# [89 rows x 15 columns]
