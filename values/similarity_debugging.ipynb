# %%
"""
This file arranges the data in the `all_data.csv` file in such a way that 
the content most similar to each user is placed at the top.
"""
import functools
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import streamlit as st

# %%
df = pd.read_csv('../data/all_data.csv', index_col=0)

# %%
df.head(2)
# Out:
#   category                                              title  \
# 0     CBBC  Operation Ouch! - Series 9: 11. Blink and You’...
# 1     CBBC  The Worst Witch - Series 4: 1. The Three Impos...
#
#                                                 tags age_rating  \
# 0  BBC, iPlayer, TV, Operation Ouch!, Series 9: 1...         PG
# 1  BBC, iPlayer, TV, The Worst Witch, Series 4: 1...         PG
#
#                    rating_description  \
# 0  injury detail, rude humour, threat
# 1                              threat
#
#                                          description  representation  \
# 0  Why is Dr Xand dressed as a bird in the lab? F...             3.0
# 1  A botched potions experiment leaves Mildred wi...             3.0
#
#   duration_txt  duration_sec  first_broadcast  ...  \
# 0      28 mins          1692  5pm 17 Mar 2021  ...
# 1      28 mins          1693      27 Jan 2020  ...
#
#                                             synopsis  \
# 0  Why is Dr Xand dressed as a bird in the lab? F...
# 1  When a botched potions experiment leaves Mildr...
#
#                                 synopsis_nostopwords  unsuitable_ratio  \
# 0  dr xand dressed bird lab? find blink today ’ e...              -0.0
# 1  botched potion experiment leaf mildred whole n...              -0.0
#
#   unsuitable_ratio2 age_rating_numeric    cas48    cas911   cas1214   cas1517  \
# 0              -0.2               0.71  0.18152  0.136690  0.006530 -0.222920
# 1              -0.0               0.71  0.21404  0.164435  0.029725 -0.204455
#
#   diversity
# 0  0.989698
# 1  0.985583
#
# [2 rows x 29 columns]

# %%
# Gets similarity scores for all other movies
def get_similarities(movie_index):
    similarities = similarities_df.loc[movie_index]
    # similarities.drop(movie_index, inplace=True)
    return similarities.rename('similarity').to_frame()

# Scales relevant features to domain [0, 1]
def scale_features(movie_df):
    scaler = MinMaxScaler((0,1))
    scaler.fit(movie_df.similarity.to_frame())
    movie_df['similarity_scaled'] = scaler.transform(movie_df.similarity.to_frame())
    scaler.fit(movie_df.diversity.to_frame())
    movie_df['diversity_scaled'] = scaler.transform(movie_df.diversity.to_frame())
    return movie_df

# Calculates weighter average for relevant (scaled) features
def weighted_score(movie, similarity_weight, diversity_weight):
    sw = movie ['similarity_scaled'] * similarity_weight
    dw = movie['diversity_scaled'] * diversity_weight
    total_weights = similarity_weight + diversity_weight
    return (sw + dw) / total_weights

# recommmends the movies + uses function from above
def recommend_movies(movie_index, diversity_factor=0.5, similarity_factor=1):
    # Filter movies with the sentiement thats is given in streamlit
    filtered_df = df[df['vader_sentiment'] == "Positive"] 
    similarities = get_similarities(movie_index)
    # DataFrame with relevant features for filtered movies
    movie_df = filtered_df.join(similarities)
    movie_df = scale_features(movie_df)
    # Calculate the weighted score
    weight_func = functools.partial(weighted_score, 
                                    similarity_weight=similarity_factor,
                                    diversity_weight=diversity_factor)
    movie_df['recommender_score'] = movie_df.apply(weight_func, axis='columns')
    return movie_df.sort_values('recommender_score', ascending=False)

# %%
# Calculate the diversity score
similarities_df = pd.read_csv('../data/all_data_similarity.csv')

# %%
one = recommend_movies(1)
one.head()
# Out:
# /Users/michelleuni/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:479: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /Users/michelleuni/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:480: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
#    category                                              title  \
# 2      CBBC   Shaun the Sheep - Series 4: 6. The Smelly Farmer
# 16     CBBC    Malory Towers - Series 2: 13. The Lost Treasure
# 19     CBBC       Shaun the Sheep - Series 5: 20. Sheep Farmer
# 22     CBBC  Danger Mouse - Series 1: 24. Escape from Big Head
# 32    Films                                         The Keeper
#
#                                                  tags age_rating  \
# 2   BBC, iPlayer, TV, Shaun the Sheep, Series 4: 6...          U
# 16  BBC, iPlayer, TV, Malory Towers, Series 2: 13....          U
# 19  BBC, iPlayer, TV, Shaun the Sheep, Series 5: 2...          U
# 22  BBC, iPlayer, TV, Danger Mouse, Series 1: 24. ...          U
# 32                       BBC, iPlayer, TV, The Keeper         15
#
#           rating_description  \
# 2                      clean
# 16                     clean
# 19                     clean
# 22  very mild fantasy action
# 32           strong language
#
#                                           description  representation  \
# 2   Shaun, Bitzer and the flock decide to give the...             NaN
# 16  Darrell and Sally make a dramatic discovery, b...             3.0
# 19  Timmy sees a particularly grumpy farmer giving...             NaN
# 22  The Big Head base computer locks up everyone i...             NaN
# 32  At the end of WWII, Bert Trautmann stays in th...             1.0
#
#    duration_txt  duration_sec     first_broadcast  ... age_rating_numeric  \
# 2        7 mins           425  3:50pm 10 Feb 2014  ...               1.00
# 16      25 mins          1495         22 Nov 2021  ...               1.00
# 19       7 mins           420  3:50pm 18 Nov 2016  ...               1.00
# 22      11 mins           664  7:25am 24 Feb 2016  ...               1.00
# 32     109 mins          6554                2018  ...               0.21
#
#       cas48    cas911   cas1214   cas1517  diversity similarity  \
# 2   0.30144  0.351305  0.401035  0.550135   0.987138        NaN
# 16  0.69390  0.743765  0.793495  0.844480   0.989856        NaN
# 19  0.69814  0.748005  0.797735  0.847660   0.985867        NaN
# 22  0.29602  0.246060  0.096140 -0.152705   0.987758        NaN
# 32  0.38160  0.442700  0.541900  0.639900   0.988112        NaN
#
#     similarity_scaled  diversity_scaled recommender_score
# 2                 NaN          0.553257               NaN
# 16                NaN          0.749886               NaN
# 19                NaN          0.461284               NaN
# 22                NaN          0.598063               NaN
# 32                NaN          0.623697               NaN
#
# [5 rows x 33 columns]

# %%
two = recommend_movies(140)
two.head()
# Out:
# /Users/michelleuni/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:479: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# /Users/michelleuni/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:480: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
#    category                                              title  \
# 2      CBBC   Shaun the Sheep - Series 4: 6. The Smelly Farmer
# 16     CBBC    Malory Towers - Series 2: 13. The Lost Treasure
# 19     CBBC       Shaun the Sheep - Series 5: 20. Sheep Farmer
# 22     CBBC  Danger Mouse - Series 1: 24. Escape from Big Head
# 32    Films                                         The Keeper
#
#                                                  tags age_rating  \
# 2   BBC, iPlayer, TV, Shaun the Sheep, Series 4: 6...          U
# 16  BBC, iPlayer, TV, Malory Towers, Series 2: 13....          U
# 19  BBC, iPlayer, TV, Shaun the Sheep, Series 5: 2...          U
# 22  BBC, iPlayer, TV, Danger Mouse, Series 1: 24. ...          U
# 32                       BBC, iPlayer, TV, The Keeper         15
#
#           rating_description  \
# 2                      clean
# 16                     clean
# 19                     clean
# 22  very mild fantasy action
# 32           strong language
#
#                                           description  representation  \
# 2   Shaun, Bitzer and the flock decide to give the...             NaN
# 16  Darrell and Sally make a dramatic discovery, b...             3.0
# 19  Timmy sees a particularly grumpy farmer giving...             NaN
# 22  The Big Head base computer locks up everyone i...             NaN
# 32  At the end of WWII, Bert Trautmann stays in th...             1.0
#
#    duration_txt  duration_sec     first_broadcast  ... age_rating_numeric  \
# 2        7 mins           425  3:50pm 10 Feb 2014  ...               1.00
# 16      25 mins          1495         22 Nov 2021  ...               1.00
# 19       7 mins           420  3:50pm 18 Nov 2016  ...               1.00
# 22      11 mins           664  7:25am 24 Feb 2016  ...               1.00
# 32     109 mins          6554                2018  ...               0.21
#
#       cas48    cas911   cas1214   cas1517  diversity similarity  \
# 2   0.30144  0.351305  0.401035  0.550135   0.987138        NaN
# 16  0.69390  0.743765  0.793495  0.844480   0.989856        NaN
# 19  0.69814  0.748005  0.797735  0.847660   0.985867        NaN
# 22  0.29602  0.246060  0.096140 -0.152705   0.987758        NaN
# 32  0.38160  0.442700  0.541900  0.639900   0.988112        NaN
#
#     similarity_scaled  diversity_scaled recommender_score
# 2                 NaN          0.553257               NaN
# 16                NaN          0.749886               NaN
# 19                NaN          0.461284               NaN
# 22                NaN          0.598063               NaN
# 32                NaN          0.623697               NaN
#
# [5 rows x 33 columns]

# %%
ratings = pd.read_csv('../data/ratings/' + 'asha' + '_ratings.csv')
highest_rated_row = ratings[ratings['rating']==ratings['rating'].max()]

# %%
highest_rated_row

# %%
highest_rated_row['showId'].iloc[0]

# %%
asha = recommend_movies(1)
asha.head(2)

# %%
ratings1 = pd.read_csv('../data/ratings/' + 'zang' + '_ratings.csv')
highest_rated_row1 = ratings1[ratings1['rating']==ratings1['rating'].max()]

# %%
highest_rated_row1

# %%
zang = recommend_movies(40)
zang.head(2)

# %%
ratings1 = pd.read_csv('../data/ratings/' + 'sine' + '_ratings.csv')
highest_rated_row1 = ratings1[ratings1['rating']==ratings1['rating'].max()]
sine = recommend_movies(highest_rated_row1['showId'].iloc[0])
sine.head(3)

# %%
ratings2 = pd.read_csv('../data/ratings/' + 'michelle' + '_ratings.csv')
highest_rated_row2 = ratings2[ratings2['rating']==ratings2['rating'].max()]
michelle = recommend_movies(highest_rated_row2['showId'].iloc[0])
michelle.head(3)

# %%
ratings1 = pd.read_csv('../data/ratings/' + 'zane' + '_ratings.csv')
highest_rated_row1 = ratings1[ratings1['rating']==ratings1['rating'].max()]
zane = recommend_movies(highest_rated_row1['showId'].iloc[0])
zane.head(3)
